# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/content/train_set_dirty.csv')

# %%
df2 = pd.read_csv('/content/test_set_nogt.csv')

# %%
df1
# Out:
#        traffic_volume holiday    temp  rain_1h  snow_1h  clouds_all  \
# 0              1493.0     NaN  287.15     0.00      0.0        90.0
# 1                 NaN     NaN  282.25     0.00      0.0        90.0
# 2                 NaN     NaN     NaN     0.00      0.0        90.0
# 3              5626.0     NaN  252.08     0.00      0.0        20.0
# 4              5357.0     NaN  291.25     1.02      0.0         NaN
# ...               ...     ...     ...      ...      ...         ...
# 38558          4727.0     NaN  267.59     0.00      0.0         5.0
# 38559          5697.0     NaN  282.16     0.00      0.0        90.0
# 38560          3009.0     NaN  256.64     0.00      0.0         1.0
# 38561           295.0     NaN  286.69     0.00      NaN         1.0
# 38562           746.0     NaN  290.18     0.00      0.0         NaN
#
#        weather_main     weather_description         date_time
# 0              Mist                     NaN  18-09-2017 22:00
# ...

# %%
df1['is_holiday'] = df1['holiday'].apply(lambda x: 0 if pd.isnull(x) or x == 'None' else 1)

# %%
df1
# Out:
#        traffic_volume holiday    temp  rain_1h  snow_1h  clouds_all  \
# 0              1493.0     NaN  287.15     0.00      0.0        90.0
# 1                 NaN     NaN  282.25     0.00      0.0        90.0
# 2                 NaN     NaN     NaN     0.00      0.0        90.0
# 3              5626.0     NaN  252.08     0.00      0.0        20.0
# 4              5357.0     NaN  291.25     1.02      0.0         NaN
# ...               ...     ...     ...      ...      ...         ...
# 38558          4727.0     NaN  267.59     0.00      0.0         5.0
# 38559          5697.0     NaN  282.16     0.00      0.0        90.0
# 38560          3009.0     NaN  256.64     0.00      0.0         1.0
# 38561           295.0     NaN  286.69     0.00      NaN         1.0
# 38562           746.0     NaN  290.18     0.00      0.0         NaN
#
#        weather_main     weather_description         date_time  is_holiday
# 0              Mist                     NaN  18-09-2017 22:00           0
# ...

# %%
df1.drop(['holiday'], axis =1, inplace = True)

# %%
df2['is_holiday'] = df2['holiday'].apply(lambda x: 0 if pd.isnull(x) or x == 'None' else 1)

# %%
df2.drop(['holiday'], axis =1, inplace = True)

# %%
df2
# Out:
#         temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     289.58     0.00      0.0          90       Clouds
# 1     290.13     0.00      0.0          90       Clouds
# 2     291.14     0.00      0.0          75       Clouds
# 3     291.72     0.00      0.0           1        Clear
# 4     281.18     0.00      0.0           1        Clear
# ...      ...      ...      ...         ...          ...
# 9636  280.28     0.00      0.0          90       Clouds
# 9637  282.18     0.00      0.0          90       Clouds
# 9638  283.48     0.00      0.0          90         Rain
# 9639  283.48     0.00      0.0          90      Drizzle
# 9640  284.20     0.25      0.0          75         Rain
#
#           weather_description         date_time  is_holiday
# 0             overcast clouds  02-10-2012 11:00           0
# 1             overcast clouds  02-10-2012 12:00           0
# 2               broken clouds  02-10-2012 13:00           0
# ...

# %%
print(df1.describe())
# Out:
#        traffic_volume          temp       rain_1h       snow_1h    clouds_all  \
# count    34748.000000  34754.000000  34860.000000  34733.000000  34659.000000
# mean      3254.207753    281.164396      0.414656      0.000242     49.472605
# std       1987.318504     13.534323     52.665546      0.008662     39.013199
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       1187.000000    272.150000      0.000000      0.000000      1.000000
# 50%       3370.500000    282.420000      0.000000      0.000000     64.000000
# 75%       4931.000000    291.770000      0.000000      0.000000     90.000000
# max       7280.000000    308.430000   9831.300000      0.510000    100.000000
#
#          is_holiday
# count  38563.000000
# mean       0.001089
# std        0.032984
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38563 entries, 0 to 38562
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       34748 non-null  float64
#  1   temp                 34754 non-null  float64
#  2   rain_1h              34860 non-null  float64
#  3   snow_1h              34733 non-null  float64
#  4   clouds_all           34659 non-null  float64
#  5   weather_main         34654 non-null  object
#  6   weather_description  34751 non-null  object
#  7   date_time            34683 non-null  object
#  8   is_holiday           38563 non-null  int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 2.6+ MB

# %%
df1[['date', 'time']] = df1['date_time'].str.split(' ',expand = True)

# %%
df1.drop(['date_time'],axis = 1,inplace = True)

# %%
df2[['date', 'time']] = df2['date_time'].str.split(' ',expand = True)

# %%
df2.drop(['date_time'],axis = 1,inplace = True)

# %%
df1
# Out:
#        traffic_volume    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0              1493.0  287.15     0.00      0.0        90.0          Mist
# 1                 NaN  282.25     0.00      0.0        90.0        Clouds
# 2                 NaN     NaN     0.00      0.0        90.0       Drizzle
# 3              5626.0  252.08     0.00      0.0        20.0          Haze
# 4              5357.0  291.25     1.02      0.0         NaN          Rain
# ...               ...     ...      ...      ...         ...           ...
# 38558          4727.0  267.59     0.00      0.0         5.0         Clear
# 38559          5697.0  282.16     0.00      0.0        90.0          Haze
# 38560          3009.0  256.64     0.00      0.0         1.0         Clear
# 38561           295.0  286.69     0.00      NaN         1.0         Clear
# 38562           746.0  290.18     0.00      0.0         NaN  Thunderstorm
#
#           weather_description  is_holiday        date   time
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38563 entries, 0 to 38562
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       34748 non-null  float64
#  1   temp                 34754 non-null  float64
#  2   rain_1h              34860 non-null  float64
#  3   snow_1h              34733 non-null  float64
#  4   clouds_all           34659 non-null  float64
#  5   weather_main         34654 non-null  object
#  6   weather_description  34751 non-null  object
#  7   is_holiday           38563 non-null  int64
#  8   date                 34683 non-null  object
#  9   time                 34683 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.9+ MB

# %%
df1.isnull().sum()
# Out:
# traffic_volume         3815
# temp                   3809
# rain_1h                3703
# snow_1h                3830
# clouds_all             3904
# weather_main           3909
# weather_description    3812
# is_holiday                0
# date                   3880
# time                   3880
# dtype: int64

# %%
df3 =df1.dropna()

# %%
df4 = df2.dropna()

# %%
df3
# Out:
#        traffic_volume    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 3              5626.0  252.08      0.0      0.0        20.0         Haze
# 7              4513.0  270.84      0.0      0.0        75.0       Clouds
# 8              3415.0  297.97      0.0      0.0        40.0       Clouds
# 9              1883.0  272.55      0.0      0.0         1.0          Fog
# 11             6651.0  300.15      0.0      0.0        75.0       Clouds
# ...               ...     ...      ...      ...         ...          ...
# 38546          6011.0  276.16      0.0      0.0        75.0       Clouds
# 38552           255.0  284.64      0.0      0.0        90.0       Clouds
# 38557           393.0  267.02      0.0      0.0        90.0       Clouds
# 38558          4727.0  267.59      0.0      0.0         5.0        Clear
# 38560          3009.0  256.64      0.0      0.0         1.0        Clear
#
#       weather_description  is_holiday        date   time
# ...

# %%
df3.duplicated().sum()
# Out:
# 5

# %%
df3.drop_duplicates(inplace = True)
# Out:
# <ipython-input-69-de9ac6306b14>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop_duplicates(inplace = True)

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df3['date'] = pd.to_datetime(df3['date'], format='%d-%m-%Y')
# Out:
# <ipython-input-71-4a3d05b2b29f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['date'] = pd.to_datetime(df3['date'], format='%d-%m-%Y')

# %%
df4['date'] = pd.to_datetime(df4['date'], format='%d-%m-%Y')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16704 entries, 3 to 38560
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       16704 non-null  float64
#  1   temp                 16704 non-null  float64
#  2   rain_1h              16704 non-null  float64
#  3   snow_1h              16704 non-null  float64
#  4   clouds_all           16704 non-null  float64
#  5   weather_main         16704 non-null  object
#  6   weather_description  16704 non-null  object
#  7   is_holiday           16704 non-null  int64
#  8   date                 16704 non-null  datetime64[ns]
#  9   time                 16704 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df3['date'] = pd.to_numeric(df3['date'], errors = 'coerce')
# Out:
# <ipython-input-74-8ed52a9d51c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['date'] = pd.to_numeric(df3['date'], errors = 'coerce')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16704 entries, 3 to 38560
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       16704 non-null  float64
#  1   temp                 16704 non-null  float64
#  2   rain_1h              16704 non-null  float64
#  3   snow_1h              16704 non-null  float64
#  4   clouds_all           16704 non-null  float64
#  5   weather_main         16704 non-null  object
#  6   weather_description  16704 non-null  object
#  7   is_holiday           16704 non-null  int64
#  8   date                 16704 non-null  int64
#  9   time                 16704 non-null  object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.4+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16704 entries, 3 to 38560
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       16704 non-null  float64
#  1   temp                 16704 non-null  float64
#  2   rain_1h              16704 non-null  float64
#  3   snow_1h              16704 non-null  float64
#  4   clouds_all           16704 non-null  float64
#  5   weather_main         16704 non-null  object
#  6   weather_description  16704 non-null  object
#  7   is_holiday           16704 non-null  int64
#  8   date                 16704 non-null  int64
#  9   time                 0 non-null      float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 1.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
x_train = df3.iloc[:,1:]

# %%
y_train = df3['traffic_volume']

# %%
for col in df3.columns:
   if (df3[col].dtype == 'object'):
    df3[col] = le.fit_transform(df3[col])
# Out:
# <ipython-input-41-2bc2ce26d145>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[col] = le.fit_transform(df3[col])
# <ipython-input-41-2bc2ce26d145>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[col] = le.fit_transform(df3[col])

# %%
df3
# Out:
#        traffic_volume    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 3              5626.0  252.08      0.0      0.0        20.0             4
# 7              4513.0  270.84      0.0      0.0        75.0             1
# 8              3415.0  297.97      0.0      0.0        40.0             1
# 9              1883.0  272.55      0.0      0.0         1.0             3
# 11             6651.0  300.15      0.0      0.0        75.0             1
# ...               ...     ...      ...      ...         ...           ...
# 38546          6011.0  276.16      0.0      0.0        75.0             1
# 38552           255.0  284.64      0.0      0.0        90.0             1
# 38557           393.0  267.02      0.0      0.0        90.0             1
# 38558          4727.0  267.59      0.0      0.0         5.0             0
# 38560          3009.0  256.64      0.0      0.0         1.0             0
#
#        weather_description  is_holiday                 date  time
# ...

# %%
df3.isnull().sum()
# Out:
# traffic_volume             0
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# is_holiday                 0
# date                       0
# time                   16704
# dtype: int64

# %%
df3['time']
# Out:
# 3       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 11      NaN
#          ..
# 38546   NaN
# 38552   NaN
# 38557   NaN
# 38558   NaN
# 38560   NaN
# Name: time, Length: 16704, dtype: float64

# %%
df3['time']
# Out:
# 3        08:00
# 7        10:00
# 8        13:00
# 9        08:00
# 11       16:00
#          ...
# 38546    15:00
# 38552    04:00
# 38557    01:00
# 38558    16:00
# 38560    22:00
# Name: time, Length: 16704, dtype: object

# %%
df3['time'] = pd.to_datetime(df3['time'], format='%H:%M').dt.time
# Out:
# <ipython-input-77-8cb34d3a7cd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['time'] = pd.to_datetime(df3['time'], format='%H:%M').dt.time

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16704 entries, 3 to 38560
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       16704 non-null  float64
#  1   temp                 16704 non-null  float64
#  2   rain_1h              16704 non-null  float64
#  3   snow_1h              16704 non-null  float64
#  4   clouds_all           16704 non-null  float64
#  5   weather_main         16704 non-null  object
#  6   weather_description  16704 non-null  object
#  7   is_holiday           16704 non-null  int64
#  8   date                 16704 non-null  int64
#  9   time                 16704 non-null  object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.4+ MB

# %%
df3['time']
# Out:
# 3        08:00:00
# 7        10:00:00
# 8        13:00:00
# 9        08:00:00
# 11       16:00:00
#            ...
# 38546    15:00:00
# 38552    04:00:00
# 38557    01:00:00
# 38558    16:00:00
# 38560    22:00:00
# Name: time, Length: 16704, dtype: object

# %%
df3['time_as_minutes'] = df3['time'].apply(lambda t: t.hour * 60 + t.minute)
# Out:
# <ipython-input-80-d0cafa6bd9be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['time_as_minutes'] = df3['time'].apply(lambda t: t.hour * 60 + t.minute)

# %%
df3
# Out:
#        traffic_volume    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 3              5626.0  252.08      0.0      0.0        20.0         Haze
# 7              4513.0  270.84      0.0      0.0        75.0       Clouds
# 8              3415.0  297.97      0.0      0.0        40.0       Clouds
# 9              1883.0  272.55      0.0      0.0         1.0          Fog
# 11             6651.0  300.15      0.0      0.0        75.0       Clouds
# ...               ...     ...      ...      ...         ...          ...
# 38546          6011.0  276.16      0.0      0.0        75.0       Clouds
# 38552           255.0  284.64      0.0      0.0        90.0       Clouds
# 38557           393.0  267.02      0.0      0.0        90.0       Clouds
# 38558          4727.0  267.59      0.0      0.0         5.0        Clear
# 38560          3009.0  256.64      0.0      0.0         1.0        Clear
#
#       weather_description  is_holiday                 date      time  \
# ...

# %%
df3.drop(['time'], axis =1,inplace = True)
# Out:
# <ipython-input-84-52f654c871a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(['time'], axis =1,inplace = True)

# %%
df3
# Out:
#        traffic_volume    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 3              5626.0  252.08      0.0      0.0        20.0         Haze
# 7              4513.0  270.84      0.0      0.0        75.0       Clouds
# 8              3415.0  297.97      0.0      0.0        40.0       Clouds
# 9              1883.0  272.55      0.0      0.0         1.0          Fog
# 11             6651.0  300.15      0.0      0.0        75.0       Clouds
# ...               ...     ...      ...      ...         ...          ...
# 38546          6011.0  276.16      0.0      0.0        75.0       Clouds
# 38552           255.0  284.64      0.0      0.0        90.0       Clouds
# 38557           393.0  267.02      0.0      0.0        90.0       Clouds
# 38558          4727.0  267.59      0.0      0.0         5.0        Clear
# 38560          3009.0  256.64      0.0      0.0         1.0        Clear
#
#       weather_description  is_holiday                 date  time_as_minutes
# ...

# %%
df3['time'] = pd.to_numeric(df3['time'], errors = 'coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-5053555d68de> in <cell line: 1>()
# ----> 1 df3['time'] = pd.to_numeric(df3['time'], errors = 'coerce')
#
# ...

# %%
df3.head()
# Out:
#     traffic_volume    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 3           5626.0  252.08      0.0      0.0        20.0         Haze
# 7           4513.0  270.84      0.0      0.0        75.0       Clouds
# 8           3415.0  297.97      0.0      0.0        40.0       Clouds
# 9           1883.0  272.55      0.0      0.0         1.0          Fog
# 11          6651.0  300.15      0.0      0.0        75.0       Clouds
#
#    weather_description  is_holiday                 date  time_as_minutes
# 3                 haze           0  1483488000000000000              480
# 7        broken clouds           0  1488326400000000000              600
# 8     scattered clouds           0  1467504000000000000              780
# 9                  fog           0  1480118400000000000              480
# 11       broken clouds           0  1533513600000000000              960

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16704 entries, 3 to 38560
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       16704 non-null  float64
#  1   temp                 16704 non-null  float64
#  2   rain_1h              16704 non-null  float64
#  3   snow_1h              16704 non-null  float64
#  4   clouds_all           16704 non-null  float64
#  5   weather_main         16704 non-null  object
#  6   weather_description  16704 non-null  object
#  7   is_holiday           16704 non-null  int64
#  8   date                 16704 non-null  int64
#  9   time_as_minutes      16704 non-null  int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
for col in df3.columns:
   if (df3[col].dtype == 'object'):
    df3[col] = le.fit_transform(df3[col])
# Out:
# <ipython-input-90-2bc2ce26d145>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[col] = le.fit_transform(df3[col])
# <ipython-input-90-2bc2ce26d145>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[col] = le.fit_transform(df3[col])

# %%
x_train = df3.iloc[:,1:]

# %%
y_train = df3['traffic_volume']

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temp                 9641 non-null   float64
#  1   rain_1h              9641 non-null   float64
#  2   snow_1h              9641 non-null   float64
#  3   clouds_all           9641 non-null   int64
#  4   weather_main         9641 non-null   object
#  5   weather_description  9641 non-null   object
#  6   is_holiday           9641 non-null   int64
#  7   date                 9641 non-null   datetime64[ns]
#  8   time                 9641 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 678.0+ KB

# %%
df4['time_as_minutes'] = df4['time'].apply(lambda t: t.hour * 60 + t.minute)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-9164dd3978d4> in <cell line: 1>()
# ----> 1 df4['time_as_minutes'] = df4['time'].apply(lambda t: t.hour * 60 + t.minute)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %%
df4['time'] = pd.to_datetime(df4['time'], format='%H:%M').dt.time

# %%
df4['time_as_minutes'] = df4['time'].apply(lambda t: t.hour * 60 + t.minute)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temp                 9641 non-null   float64
#  1   rain_1h              9641 non-null   float64
#  2   snow_1h              9641 non-null   float64
#  3   clouds_all           9641 non-null   int64
#  4   weather_main         9641 non-null   object
#  5   weather_description  9641 non-null   object
#  6   is_holiday           9641 non-null   int64
#  7   date                 9641 non-null   datetime64[ns]
#  8   time                 9641 non-null   object
#  9   time_as_minutes      9641 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 753.3+ KB

# %%
df4['date'] = pd.to_numeric(df4['date'],errors = 'coerce')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temp                 9641 non-null   float64
#  1   rain_1h              9641 non-null   float64
#  2   snow_1h              9641 non-null   float64
#  3   clouds_all           9641 non-null   int64
#  4   weather_main         9641 non-null   object
#  5   weather_description  9641 non-null   object
#  6   is_holiday           9641 non-null   int64
#  7   date                 9641 non-null   int64
#  8   time                 9641 non-null   object
#  9   time_as_minutes      9641 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 753.3+ KB

# %%
df4.drop(['time'], axis = 1, inplace = True)

# %%
for col in df4.columns:
   if (df4[col].dtype == 'object'):
    df4[col] = le.fit_transform(df4[col])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temp                 9641 non-null   float64
#  1   rain_1h              9641 non-null   float64
#  2   snow_1h              9641 non-null   float64
#  3   clouds_all           9641 non-null   int64
#  4   weather_main         9641 non-null   int64
#  5   weather_description  9641 non-null   int64
#  6   is_holiday           9641 non-null   int64
#  7   date                 9641 non-null   int64
#  8   time_as_minutes      9641 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 678.0 KB

# %%
y_pred = lr.predict(df4)

# %%
y_pred
# Out:
# array([3259.34858819, 3259.34858819, 3259.34858819, ..., 3266.86189832,
#        3266.86189832, 3266.86189832])

# %%
y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-a704e5f09c63> in <cell line: 1>()
# ----> 1 y_pred.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr1 = LogisticRegression()

# %%
lr1.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y1_predict = lr1.predict(df4)

# %%
y1_predict
# Out:
# array([356., 356., 356., ..., 356., 356., 356.])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=50, random_state=25)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=25)

# %%
y1 = model.predict(df4)

# %%
y1
# Out:
# array([4766.98, 5505.92, 5358.78, ..., 4803.96, 4863.68, 4454.94])

# %%
print(y1)
# Out:
# [4766.98 5505.92 5358.78 ... 4803.96 4863.68 4454.94]

# %%
len(y1)
# Out:
# 9641

# %%
df4
# Out:
#         temp  rain_1h  snow_1h  clouds_all  weather_main  weather_description  \
# 0     289.58     0.00      0.0          90             1                   18
# 1     290.13     0.00      0.0          90             1                   18
# 2     291.14     0.00      0.0          75             1                    2
# 3     291.72     0.00      0.0           1             0                   25
# 4     281.18     0.00      0.0           1             0                   25
# ...      ...      ...      ...         ...           ...                  ...
# 9636  280.28     0.00      0.0          90             1                   18
# 9637  282.18     0.00      0.0          90             1                   18
# 9638  283.48     0.00      0.0          90             6                   13
# 9639  283.48     0.00      0.0          90             2                   11
# 9640  284.20     0.25      0.0          75             6                   13
#
# ...

# %%
y_pred
# Out:
# array([3259.34858819, 3259.34858819, 3259.34858819, ..., 3266.86189832,
#        3266.86189832, 3266.86189832])

# %%
len(y_pred)
# Out:
# 9641

# %%
df = pd.DataFrame(y1)

# Save the DataFrame to a CSV file
df.to_csv('output.csv', index=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df5 = pd.DataFrame(y_pred)

# Save the DataFrame to a CSV file
df5.to_csv('output1.csv', index=True)
